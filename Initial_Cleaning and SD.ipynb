# %%
#importing libraries
import pandas as pd
import numpy as np
from pandasql import sqldf

# %%
#connecting to first csv
schools = pd.read_csv(r"C:\Users\amytu\OneDrive\Documents\Capstone\Drilled Down\Schools.csv")
schools.head()
# Out:
#   School Year Level  Div Num     Division Name  Sch Num  \
# 0   2015-2016   SCH        1  Accomack County       701
# 1   2015-2016   SCH        1  Accomack County       701
# 2   2015-2016   SCH        1  Accomack County       701
# 3   2015-2016   SCH        1  Accomack County       701
# 4   2015-2016   SCH        1  Accomack County       701
#
#              School Name Sch Type Low Grade  High Grade  \
# 0  Accawmacke Elementary     Elem        PK           5
# 1  Accawmacke Elementary     Elem        PK           5
# 2  Accawmacke Elementary     Elem        PK           5
# 3  Accawmacke Elementary     Elem        PK           5
# 4  Accawmacke Elementary     Elem        PK           5
#
#                        Subject  ... 2013-14 Adv Pass Rate  \
# 0             English: Reading  ...                  14.0
# 1             English: Reading  ...                  13.0
# 2             English: Reading  ...                  16.0
# ...

# %%
#checking data types
schools.dtypes
# Out:
# School Year               object
# Level                     object
# Div Num                    int64
# Division Name             object
# Sch Num                    int64
# School Name               object
# Sch Type                  object
# Low Grade                 object
# High Grade                 int64
# Subject                   object
# Test                      object
# 2013-14 Pass Rate        float64
# 2014-15 Pass Rate        float64
# 2015-16 Pass Rate        float64
# 2013-14 Adv Pass Rate    float64
# 2014-15 Adv Pass Rate    float64
# 2015-16 Adv Pass Rate    float64
# Identifier                object
# 2016-2017 Pass Rate      float64
# 2017-2018 Pass Rate      float64
# 2018-2019 Pass Rate      float64
# 2019-2020 Pass Rate      float64
# 2020-2021 Pass Rate      float64
# 2021-2022 Pass Rate      float64
# dtype: object

# %%
schools.isnull().sum()
# Out:
# School Year                  0
# Level                        0
# Div Num                      0
# Division Name                0
# Sch Num                      0
# School Name                  0
# Sch Type                     0
# Low Grade                    0
# High Grade                   0
# Subject                      0
# Test                         0
# 2013-14 Pass Rate         1022
# 2014-15 Pass Rate         4623
# 2015-16 Pass Rate         4643
# 2013-14 Adv Pass Rate     1022
# 2014-15 Adv Pass Rate     4623
# 2015-16 Adv Pass Rate     4643
# Identifier                   0
# 2016-2017 Pass Rate       6004
# 2017-2018 Pass Rate       5952
# 2018-2019 Pass Rate       5991
# 2019-2020 Pass Rate      24747
# 2020-2021 Pass Rate      10156
# 2021-2022 Pass Rate      13464
# dtype: int64

# %%
schools.isna().sum()
# Out:
# School Year                  0
# Level                        0
# Div Num                      0
# Division Name                0
# Sch Num                      0
# School Name                  0
# Sch Type                     0
# Low Grade                    0
# High Grade                   0
# Subject                      0
# Test                         0
# 2013-14 Pass Rate         1022
# 2014-15 Pass Rate         4623
# 2015-16 Pass Rate         4643
# 2013-14 Adv Pass Rate     1022
# 2014-15 Adv Pass Rate     4623
# 2015-16 Adv Pass Rate     4643
# Identifier                   0
# 2016-2017 Pass Rate       6004
# 2017-2018 Pass Rate       5952
# 2018-2019 Pass Rate       5991
# 2019-2020 Pass Rate      24747
# 2020-2021 Pass Rate      10156
# 2021-2022 Pass Rate      13464
# dtype: int64

# %%
schools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24747 entries, 0 to 24746
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   School Year            24747 non-null  object
#  1   Level                  24747 non-null  object
#  2   Div Num                24747 non-null  int64
#  3   Division Name          24747 non-null  object
#  4   Sch Num                24747 non-null  int64
#  5   School Name            24747 non-null  object
#  6   Sch Type               24747 non-null  object
#  7   Low Grade              24747 non-null  object
#  8   High Grade             24747 non-null  int64
#  9   Subject                24747 non-null  object
#  10  Test                   24747 non-null  object
#  11  2013-14 Pass Rate      23725 non-null  float64
#  12  2014-15 Pass Rate      20124 non-null  float64
#  13  2015-16 Pass Rate      20104 non-null  float64
# ...

# %%
#counting duplicates
schools.duplicated().sum()
# Out:
# 491

# %%
#visualizing duplicates to ensure they should be dropped
schools_dup = schools[schools.duplicated(keep=False)]
schools_dup
# Out:
#       School Year Level  Div Num       Division Name  Sch Num  \
# 613     2015-2016   SCH        3   Alleghany County      1041
# 614     2015-2016   SCH        3   Alleghany County      1041
# 615     2015-2016   SCH        3   Alleghany County      1041
# 624     2015-2016   SCH        3   Alleghany County      1041
# 625     2015-2016   SCH        3   Alleghany County      1041
# ...           ...   ...      ...                 ...      ...
# 24018   2015-2016   SCH       94  Washington County      1080
# 24451   2015-2016   SCH      132    Winchester City        80
# 24452   2015-2016   SCH      132    Winchester City        80
# 24453   2015-2016   SCH      132    Winchester City        80
# 24454   2015-2016   SCH      132    Winchester City        80
#
#                          School Name Sch Type Low Grade  High Grade  \
# 613         Mountain View Elementary     Elem        KG           5
# 614         Mountain View Elementary     Elem        KG           5
# ...

# %%
#dropping duplicates from dataset
schools2 = schools.drop_duplicates(keep='first').reset_index()
schools2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24256 entries, 0 to 24255
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  24256 non-null  int64
#  1   School Year            24256 non-null  object
#  2   Level                  24256 non-null  object
#  3   Div Num                24256 non-null  int64
#  4   Division Name          24256 non-null  object
#  5   Sch Num                24256 non-null  int64
#  6   School Name            24256 non-null  object
#  7   Sch Type               24256 non-null  object
#  8   Low Grade              24256 non-null  object
#  9   High Grade             24256 non-null  int64
#  10  Subject                24256 non-null  object
#  11  Test                   24256 non-null  object
#  12  2013-14 Pass Rate      23319 non-null  float64
#  13  2014-15 Pass Rate      19706 non-null  float64
# ...

# %%
#recounting nulls - similar
schools2.isna().sum()
# Out:
# index                        0
# School Year                  0
# Level                        0
# Div Num                      0
# Division Name                0
# Sch Num                      0
# School Name                  0
# Sch Type                     0
# Low Grade                    0
# High Grade                   0
# Subject                      0
# Test                         0
# 2013-14 Pass Rate          937
# 2014-15 Pass Rate         4550
# 2015-16 Pass Rate         4559
# 2013-14 Adv Pass Rate      937
# 2014-15 Adv Pass Rate     4550
# 2015-16 Adv Pass Rate     4559
# Identifier                   0
# 2016-2017 Pass Rate       5919
# 2017-2018 Pass Rate       5867
# 2018-2019 Pass Rate       5906
# 2019-2020 Pass Rate      24256
# 2020-2021 Pass Rate       9666
# 2021-2022 Pass Rate      12973
# dtype: int64

# %%
schools2.to_csv(r"C:\Users\amytu\OneDrive\Documents\Capstone\Drilled Down\School_Data.csv")

# %%
standdev = pd.DataFrame(schools2[['2013-14 Pass Rate','2014-15 Pass Rate', '2015-16 Pass Rate', '2016-2017 Pass Rate', '2017-2018 Pass Rate', '2018-2019 Pass Rate']].std(axis = 1))
standdev
# Out:
#               0
# 0      5.645057
# 1      7.420692
# 2      4.792355
# 3           NaN
# 4           NaN
# ...         ...
# 24251  7.589466
# 24252  7.589466
# 24253       NaN
# 24254  7.250287
# 24255  7.250287
#
# [24256 rows x 1 columns]

# %%
standdev.sum()
# Out:
# 0    144456.541953
# dtype: float64

# %%
standdev.isna().sum()
# Out:
# 0    4461
# dtype: int64

# %%
23256 - 4461
# Out:
# 18795

# %%
144456.54/18795
# Out:
# 7.68590263367917

# %% [markdown]
# ## Repeating all above steps with second dataset

# %%
#connecting to second csv
subgroups = pd.read_csv(r"C:\Users\amytu\OneDrive\Documents\Capstone\Subgroups\Subgroups.csv")
subgroups.head()
# Out:
#   Level  Div Num          Div Name  Sch Num            School Name  \
# 0   Sch        1  Accomack County       701  Accawmacke Elementary
# 1   Sch        1  Accomack County       701  Accawmacke Elementary
# 2   Sch        1  Accomack County       701  Accawmacke Elementary
# 3   Sch        1  Accomack County       701  Accawmacke Elementary
# 4   Sch        1  Accomack County       701  Accawmacke Elementary
#
#   School Type Low Grade  High Grade                      Subject  \
# 0        Elem        PK           5             English: Reading
# 1        Elem        PK           5             English: Writing
# 2        Elem        PK           5  History and Social Sciences
# 3        Elem        PK           5                  Mathematics
# 4        Elem        PK           5                      Science
#
#        Subgroup  2013-2014 Pass Rate  2014-2015 Pass Rate  \
# 0  All Students                 67.0                 72.0
# ...

# %%
#pass rate rows came in as float so will not need to change datatype
subgroups.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94054 entries, 0 to 94053
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Level                94054 non-null  object
#  1   Div Num              94054 non-null  int64
#  2   Div Name             94054 non-null  object
#  3   Sch Num              94054 non-null  int64
#  4   School Name          94054 non-null  object
#  5   School Type          94054 non-null  object
#  6   Low Grade            94054 non-null  object
#  7   High Grade           94054 non-null  int64
#  8   Subject              94054 non-null  object
#  9   Subgroup             94054 non-null  object
#  10  2013-2014 Pass Rate  85072 non-null  float64
#  11  2014-2015 Pass Rate  73659 non-null  float64
#  12  2015-2016 Pass Rate  74521 non-null  float64
#  13  Identifier           94054 non-null  object
#  14  2016-2017 Pass Rate  73788 non-null  float64
# ...

# %%
subgroups.isna().sum()
# Out:
# Level                      0
# Div Num                    0
# Div Name                   0
# Sch Num                    0
# School Name                0
# School Type                0
# Low Grade                  0
# High Grade                 0
# Subject                    0
# Subgroup                   0
# 2013-2014 Pass Rate     8982
# 2014-2015 Pass Rate    20395
# 2015-2016 Pass Rate    19533
# Identifier                 0
# 2016-2017 Pass Rate    20266
# 2017-2018 Pass Rate    20455
# 2018-2019 Pass Rate    20517
# 2019-2020 Pass Rate    94054
# 2020-2021 Pass Rate    41544
# 2021-2022 Pass Rate    44226
# dtype: int64

# %%
#counting duplicate rows
subgroups.duplicated().sum()
# Out:
# 2866

# %%
#visualizing duplicates to ensure they should be dropped
subgroup_dup = subgroups[subgroups.duplicated(keep=False)]
subgroup_dup
# Out:
#       Level  Div Num                         Div Name  Sch Num  \
# 277     Sch        2                Albemarle County       160
# 278     Sch        2                Albemarle County       160
# 606     Sch        2                Albemarle County       340
# 607     Sch        2                Albemarle County       340
# 610     Sch        2                Albemarle County       340
# ...     ...      ...                              ...      ...
# 92748   Sch      131  Williamsburg-James City County       203
# 92828   Sch      132                 Winchester City        80
# 92829   Sch      132                 Winchester City        80
# 92831   Sch      132                 Winchester City        80
# 92832   Sch      132                 Winchester City        80
#
#                          School Name School Type Low Grade  High Grade  \
# 277            Agnor-Hurt Elementary        Elem        PK           5
# ...

# %%
#dropping duplicates
subgroups2 = subgroups.drop_duplicates(keep='first').reset_index()
subgroups2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91188 entries, 0 to 91187
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                91188 non-null  int64
#  1   Level                91188 non-null  object
#  2   Div Num              91188 non-null  int64
#  3   Div Name             91188 non-null  object
#  4   Sch Num              91188 non-null  int64
#  5   School Name          91188 non-null  object
#  6   School Type          91188 non-null  object
#  7   Low Grade            91188 non-null  object
#  8   High Grade           91188 non-null  int64
#  9   Subject              91188 non-null  object
#  10  Subgroup             91188 non-null  object
#  11  2013-2014 Pass Rate  83030 non-null  float64
#  12  2014-2015 Pass Rate  71899 non-null  float64
#  13  2015-2016 Pass Rate  72674 non-null  float64
#  14  Identifier           91188 non-null  object
# ...

# %%
#recounting nulls - similar
subgroups2.isna().sum()
# Out:
# index                      0
# Level                      0
# Div Num                    0
# Div Name                   0
# Sch Num                    0
# School Name                0
# School Type                0
# Low Grade                  0
# High Grade                 0
# Subject                    0
# Subgroup                   0
# 2013-2014 Pass Rate     8158
# 2014-2015 Pass Rate    19289
# 2015-2016 Pass Rate    18514
# Identifier                 0
# 2016-2017 Pass Rate    19029
# 2017-2018 Pass Rate    19215
# 2018-2019 Pass Rate    19227
# 2019-2020 Pass Rate    91188
# 2020-2021 Pass Rate    38905
# 2021-2022 Pass Rate    41720
# dtype: int64

# %%
subgroups2.to_csv(r"C:\Users\amytu\OneDrive\Documents\Capstone\Subgroups\Subgroups_Data.csv")

# %%
 subgroups2[["index", "Div Num", "Sch Num", "High Grade", "2019-2020 Pass Rate", "2020-2021 Pass Rate", "2021-2022 Pass Rate"]] = subgroups2[["index", "Div Num", "Sch Num", "High Grade", "2019-2020 Pass Rate", "2020-2021 Pass Rate", "2021-2022 Pass Rate"]].astype(str)

# %%
subgroups2.dtypes
# Out:
# index                   object
# Level                   object
# Div Num                 object
# Div Name                object
# Sch Num                 object
# School Name             object
# School Type             object
# Low Grade               object
# High Grade              object
# Subject                 object
# Subgroup                object
# 2013-2014 Pass Rate    float64
# 2014-2015 Pass Rate    float64
# 2015-2016 Pass Rate    float64
# Identifier              object
# 2016-2017 Pass Rate    float64
# 2017-2018 Pass Rate    float64
# 2018-2019 Pass Rate    float64
# 2019-2020 Pass Rate     object
# 2020-2021 Pass Rate     object
# 2021-2022 Pass Rate     object
# dtype: object

# %%
standdev2 = pd.DataFrame(subgroups[['2013-2014 Pass Rate','2014-2015 Pass Rate', '2015-2016 Pass Rate', '2016-2017 Pass Rate', '2017-2018 Pass Rate', '2018-2019 Pass Rate']].std(axis = 1))
standdev2
# Out:
#               0
# 0      2.875181
# 1           NaN
# 2      5.501515
# 3      6.772493
# 4      9.159694
# ...         ...
# 94049  3.983298
# 94050  4.676181
# 94051  4.676181
# 94052  5.403702
# 94053  5.403702
#
# [94054 rows x 1 columns]

# %%
standdev2.sum()
# Out:
# 0    690280.452044
# dtype: float64

# %%
standdev2.isna().sum()
# Out:
# 0    16001
# dtype: int64

# %%
94054 - 16001
# Out:
# 78053

# %%
690280.45/78053
# Out:
# 8.84374015092309

# %%
subgroups2["School Type"].unique()
# Out:
# array(['Elem'], dtype=object)

# %%
schools2["Sch Type"].unique()
# Out:
# array(['Elem'], dtype=object)
